# %%
import sys
sys.path.append('C:/Users/hyuck/MyPython/Study/4_usa_stock_simulation')

from simulation import Simulation

# %%
SIM_START_DATE = '2018-01-01'
SIM_END_DATE   = '2022-12-31'
FIGURE = False

# %%
TICKERS = ['SPY','AAPL','QQQ','QLD','TQQQ','TSLA']

# %%
for TICKER in TICKERS:
    print('-'*100)
    print('> {}'.format(TICKER))
    print('-'*100)
    Simulation(
        TICKER=TICKER,
        SIM_START_DATE=SIM_START_DATE,
        SIM_END_DATE=SIM_END_DATE,
        FIGURE=FIGURE,
    )
# Out:
# ----------------------------------------------------------------------------------------------------
# > SPY
# ----------------------------------------------------------------------------------------------------
# > 시뮬레이션 기간  : 2018-01-02 ~ 2022-12-01 (5 Year)
# > 보유한 SPY의 수  : 80
# > 구매 총가격 ($)  : 25168.838
# > 구매 평단가 ($)  : 314.610
#
# > 구매 총가격 (₩)  : 32,760,262
# > 판매 총가격 (₩)  : 40,609,501
# > 이익 (₩)         : 7,849,239
# > 이익비           : 1.240
#
# ----------------------------------------------------------------------------------------------------
# > AAPL
# ----------------------------------------------------------------------------------------------------
# > 시뮬레이션 기간  : 2018-01-02 ~ 2022-12-01 (5 Year)
# > 보유한 SPY의 수  : 345
# > 구매 총가격 ($)  : 25375.283
# > 구매 평단가 ($)  : 73.552
#
# > 구매 총가격 (₩)  : 33,028,976
# > 판매 총가격 (₩)  : 69,604,129
# > 이익 (₩)         : 36,575,153
# > 이익비           : 2.107
#
# ----------------------------------------------------------------------------------------------------
# > QQQ
# ----------------------------------------------------------------------------------------------------
# > 시뮬레이션 기간  : 2018-01-02 ~ 2022-12-01 (5 Year)
# > 보유한 SPY의 수  : 111
# > 구매 총가격 ($)  : 25378.448
# > 구매 평단가 ($)  : 228.635
#
# > 구매 총가격 (₩)  : 33,033,095
# > 판매 총가격 (₩)  : 44,118,355
# > 이익 (₩)         : 11,085,259
# > 이익비           : 1.336
#
# ----------------------------------------------------------------------------------------------------
# > QLD
# ----------------------------------------------------------------------------------------------------
# > 시뮬레이션 기간  : 2018-01-02 ~ 2022-12-01 (5 Year)
# > 보유한 SPY의 수  : 777
# > 구매 총가격 ($)  : 25379.560
# > 구매 평단가 ($)  : 32.664
#
# > 구매 총가격 (₩)  : 33,034,542
# > 판매 총가격 (₩)  : 45,389,781
# > 이익 (₩)         : 12,355,239
# > 이익비           : 1.374
#
# ----------------------------------------------------------------------------------------------------
# > TQQQ
# ----------------------------------------------------------------------------------------------------
# > 시뮬레이션 기간  : 2018-01-02 ~ 2022-12-01 (5 Year)
# > 보유한 SPY의 수  : 1187
# > 구매 총가격 ($)  : 25402.446
# > 구매 평단가 ($)  : 21.401
#
# > 구매 총가격 (₩)  : 33,064,332
# > 판매 총가격 (₩)  : 37,961,213
# > 이익 (₩)         : 4,896,880
# > 이익비           : 1.148
#
# ----------------------------------------------------------------------------------------------------
# > TSLA
# ----------------------------------------------------------------------------------------------------
# > 시뮬레이션 기간  : 2018-01-02 ~ 2022-12-01 (5 Year)
# > 보유한 SPY의 수  : 652
# > 구매 총가격 ($)  : 25370.911
# > 구매 평단가 ($)  : 38.912
#
# > 구매 총가격 (₩)  : 33,023,284
# > 판매 총가격 (₩)  : 152,868,452
# > 이익 (₩)         : 119,845,167
# > 이익비           : 4.629
